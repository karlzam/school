# %% [markdown]
# # load Pandas (as pd)
# # load numpy (as np)
# # load matplotlib (as plt)
# # For more detailed information see:
# # Pandas: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
#
# # Numpy : https://numpy.org/
# # Matplotlib: https://matplotlib.org/

# %%
import pandas as pd
import numpy as np
from matplotlib  import pyplot as plt
print('Loading from repositories, Done!')
# Out:
# Loading from repositories, Done!

# %% [markdown]
# # Load your data by numpy (tables)

# %%
inp_red= np.load('inp_redshift.npy')
inp_alfa= np.load('inp_alfalfa.npy')


tar_red= np.load('tar_redshift.npy')
tar_alfa= np.load('tar_alfalfa.npy')

print('Data loading, Done!')
# Out:
# Data loading, Done!

# %% [markdown]
# # get some information like the shape and mean

# %%
print ('shape inp_red = ', np.shape(inp_red),' and    shape tar_red = ', np.shape(tar_red))
print ('shape inp_alfa = ', np.shape(inp_alfa),' and    shape tar_alfa = ', np.shape(tar_alfa))
# Out:
# shape inp_red =  (713, 7)  and    shape tar_red =  (713,)
# shape inp_alfa =  (13674, 15)  and    shape tar_alfa =  (13674,)

# %%
np.mean(inp_red, axis=0)
# Out:
# array([0.20019776, 0.77058906, 0.69948527, 0.34240393, 0.33357644,
#        0.27765778, 0.20329593])

# %%
print (np.min(inp_red, axis=0))
# Out:
# [-2.064 -0.144 -0.296 -0.384 -0.958 -0.704 -0.972]

# %%
print (np.max(inp_red, axis=0))
# Out:
# [1.869 2.723 1.657 1.092 1.294 1.299 0.952]

# %% [markdown]
# # Plot histogram (of a column)

# %%
plt.hist(inp_red[:,6])
# Out:
# (array([  2.,   2.,   8.,  10.,  84., 194., 283., 102.,  23.,   5.]),
#  array([-0.972 , -0.7796, -0.5872, -0.3948, -0.2024, -0.01  ,  0.1824,
#          0.3748,  0.5672,  0.7596,  0.952 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Plotting clounn 3 vs. clumn 5

# %%
plt.plot(inp_red[:,2],inp_red[:,4],'.r')

# %% [markdown]
#  ## Loading a data set (CSV) with Pandas

# %%
Excel_Data= pd.read_csv('Height_Weight.csv')
print('loading data, Done!')
# Out:
# loading data, Done!

# %% [markdown]
# # Getting information

# %%
Excel_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   25000 non-null  int64
#  1   Height  25000 non-null  float64
#  2   Weight  25000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 586.1 KB

# %%
Excel_Data.values  # converting to a Numpy array. The first column is index (i.e., not information)
# Out:
# array([[1.000000e+00, 6.578331e+01, 1.129925e+02],
#        [2.000000e+00, 7.151521e+01, 1.364873e+02],
#        [3.000000e+00, 6.939874e+01, 1.530269e+02],
#        ...,
#        [2.499800e+04, 6.469855e+01, 1.182655e+02],
#        [2.499900e+04, 6.752918e+01, 1.322682e+02],
#        [2.500000e+04, 6.887761e+01, 1.248742e+02]])

# %%
Informative_data =  Excel_Data.values[:,1:]

# %%
type(Informative_data)  # the type of the data
# Out:
# numpy.ndarray

# %%
Informative_data.shape #the shape
# Out:
# (25000, 2)

# %% [markdown]
# # Plotting features (X2 vs. X1)

# %%
X1= Excel_Data[["Height"]].values   
X2= Excel_Data[["Weight"]].values

# %%
plt.plot(X1, X2,'.')
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')
